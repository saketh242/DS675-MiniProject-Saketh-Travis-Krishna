# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df_data = pd.read_csv('data/Training_indian_liver_disease_dataset.csv')

df_features = df_data[['Age',
                       'BMI',
                       'Sleep_Hours',
                       'ALT',
                       'AST',
                       'Bilirubin',
                       'Albumin',
                       'Platelets',
                       'Alk_Phosphatase'
                       ]]

X = df_features.iloc[:, 1:].values
y = df_data.iloc[:, -1].values
print(df_features)
print(y)
# Out:
#        Age   BMI  Sleep_Hours    ALT    AST  Bilirubin  Albumin  Platelets  \
# 0       49  21.0          4.9  25.58  29.30       1.26     4.74        334
# 1       49  22.6          8.2  22.98  30.41       0.73     3.67        224
# 2       66  19.5          5.1  65.46  45.63       0.70     4.27        304
# 3       75  21.5          6.2  55.88  74.40       0.98     4.12        367
# 4       51  22.8          7.8  72.63  49.17       2.79     4.12         49
# ...    ...   ...          ...    ...    ...        ...      ...        ...
# 67995   44  29.4          6.2  54.76  39.53       1.77     4.44        166
# 67996   48  19.6          8.4  54.73  33.67       0.41     3.90        396
# 67997   45  29.1          8.8  17.76  32.66       0.34     3.99        166
# 67998   38  19.9          5.6  45.94  18.90       0.85     4.66        330
# 67999   43  26.1          6.4  39.20  30.45       0.80     3.55        246
#
#        Alk_Phosphatase
# 0                  119
# 1                   89
# 2                  109
# 3                  102
# 4                  114
# ...                ...
# 67995               87
# 67996              118
# 67997              103
# 67998              107
# 67999              101
#
# [68000 rows x 9 columns]
# ['Fatty_Liver' 'Normal' 'Fatty_Liver' ... 'Normal' 'Fatty_Liver'
#  'Fatty_Liver']
